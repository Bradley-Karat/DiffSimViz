# %% [markdown]
# # Global/Universal Initializations

# %%
import random
import numpy
from math import sqrt
from scipy.stats import norm
import numpy as np
numofmol = 8
N = 20
radius = 0.2
vradius=0.2
theta = 0

delta = 0.4
# Total time.
T = 7
# Time step size
dt = T/N

traj = np.zeros((2,N,numofmol))
initialrot = np.zeros((numofmol,2))
where = np.zeros((numofmol))

ratiointra = 0.5

# %%
# function is also used in the stick cross generation
def make_stick_line(theta,radius):

    y = np.linspace(-2,2,100)

    xlow = np.zeros((100,))
    xlow[:] = -radius
    xhigh = np.zeros((100,))
    xhigh[:] = radius

    line1 = np.c_[xlow,y]
    line2 = np.c_[xhigh,y]

    c, s = np.cos(theta), np.sin(theta)
    rot = np.array(((c, -s), (s, c)))

    line1rot = line1 @ rot
    line2rot = line2 @ rot
    

    return line1rot, line2rot
line1, line2 = make_stick_line(theta,radius)

# %% [markdown]
# # Vertical Stick

# %%
"""
brownian() implements one dimensional Brownian motion (i.e. the Wiener process).
"""


def brownian_singlestep(x0, n, dt, delta, radius, theta, out=None):
    """
    Generate an instance of Brownian motion (i.e. the Wiener process):

        X(t) = X(0) + N(0, delta**2 * t; 0, t)

    where N(a,b; t0, t1) is a normally distributed random variable with mean a and
    variance b.  The parameters t0 and t1 make explicit the statistical
    independence of N on different time intervals; that is, if [t0, t1) and
    [t2, t3) are disjoint intervals, then N(a, b; t0, t1) and N(a, b; t2, t3)
    are independent.
    
    Written as an iteration scheme,

        X(t + dt) = X(t) + N(0, delta**2 * dt; t, t+dt)


    If `x0` is an array (or array-like), each value in `x0` is treated as
    an initial condition, and the value returned is a numpy array with one
    more dimension than `x0`.

    Arguments
    ---------
    x0 : float or numpy array (or something that can be converted to a numpy array
         using numpy.asarray(x0)).
        The initial condition(s) (i.e. position(s)) of the Brownian motion.
    n : int
        The number of steps to take.
    dt : float
        The time step.
    delta : float
        delta determines the "speed" of the Brownian motion.  The random variable
        of the position at time t, X(t), has a normal distribution whose mean is
        the position at time t=0 and whose variance is delta**2*t.
    out : numpy array or None
        If `out` is not None, it specifies the array in which to put the
        result.  If `out` is None, a new numpy array is created and returned.
    sticks : int
        The number of sticks (pairs of wall) in the simulation.
        Used for conditionals as more collisions will need to be checked.

    Returns
    -------
    A numpy array of floats with shape `x0.shape + (n,)`.
    
    Note that the initial value `x0` is not included in the returned array.
    """

    x0 = np.asarray(x0)
    # For each element of x0, generate a sample of n numbers from a
    # normal distribution.
    coordhold = np.copy(x0)
    coordfinal = np.zeros((2,n))
    #coordfinal = []

    c, s = np.cos(theta), np.sin(theta)
    rot = np.array(((c, -s), (s, c)))

    if x0[0] < -radius:
        where=0
        for i in range(n):
            if i == 0:
                coordfinal[:,0] = x0
            #print(i)
            else:
                r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                if (r[0] + coordhold[0]) < -radius:
                    coordhold += r
                    coordfinal[:,i] = coordhold
                else:
                    while (r[0] + coordhold[0]) > -radius:
                        r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                    coordhold += r
                    coordfinal[:,i] = coordhold
    elif x0[0] > radius:
        where=0
        for i in range(n):
            if i == 0:
                coordfinal[:,0] = x0
            #print(i)
            else:
                r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                if (r[0] + coordhold[0]) > radius:
                    coordhold += r
                    coordfinal[:,i] = coordhold
                else:
                    while (r[0] + coordhold[0]) < radius:
                        r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                    coordhold += r
                    coordfinal[:,i] = coordhold
    else:
        where = 1
        for i in range(n):
            if i == 0:
                coordfinal[:,0] = x0
            #print(i)
            else:
                r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                if (r[0] + coordhold[0]) > -radius and (r[0] + coordhold[0]) < radius:
                    coordhold += r
                    coordfinal[:,i] = coordhold
                else:
                    while (r[0] + coordhold[0]) < -radius or (r[0] + coordhold[0]) > radius:
                        r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                    coordhold += r
                    coordfinal[:,i] = coordhold

    coordfinal = np.squeeze(np.array(coordfinal)) 
    # Add the initial condition.
    #coordfinal += np.expand_dims(x0, axis=-1)
    coordfinal = np.transpose(rot) @ coordfinal
    initialrot = np.transpose(rot) @ x0
    
    return coordfinal,where,initialrot

# %%
initialinx = numpy.random.uniform(low=-radius, high=radius, size=(round(numofmol*ratiointra),1))
initialiny = numpy.random.uniform(low=-1.5, high=1.5, size=(round(numofmol*ratiointra),1))
initialincomb = np.concatenate((initialinx,initialiny),axis=1)

initialleftx = numpy.random.uniform(low=-1.5, high=-radius, size=(round(numofmol*(1-ratiointra)*0.5),1))
initiallefty = numpy.random.uniform(low=-1.5, high=1.5, size=(round(numofmol*(1-ratiointra)*0.5),1))
initialleftcomb = np.concatenate((initialleftx,initiallefty),axis=1)

initialrightx = numpy.random.uniform(low=radius, high=1.5, size=(round(numofmol*(1-ratiointra)*0.5),1))
initialrighty = numpy.random.uniform(low=-1.5, high=1.5, size=(round(numofmol*(1-ratiointra)*0.5),1))
initialrightcomb = np.concatenate((initialrightx,initialrighty),axis=1)

initial = np.concatenate((initialincomb,initialleftcomb,initialrightcomb),axis=0)

# %%
from IPython.display import display, clear_output
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111)
filenames = []

for i in range(N):
    print(i)
    for j in range(numofmol):

        new_y = traj[1,:i,j]
        new_x = traj[0,:i,j]

        if i == 0:
            ax.scatter(traj[0,0,j],traj[1,0,j],color='black')
        #elif i==N-1:
            #ax.scatter(traj[0,i,j],traj[1,i,j])
        if where[j] == 1:
            ax.plot(new_x,new_y,'deepskyblue')
        else:
            ax.plot(new_x,new_y,'lightskyblue')
        ax.plot(line1[:,0],line1[:,1],color='black')
        ax.plot(line2[:,0],line2[:,1],color='black')
        plt.xlim((-1.5, 1.5))   # set the xlim to left, right
        plt.ylim((-1.5, 1.5)) 


    plt.savefig(f'{outputdirectory}/test_{i}.png')
    filenames.append(f'test_{i}.png')
    #ax.clear()
    #display(fig)
    clear_output(wait=True)
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\evanc\OneDrive - University of Waterloo\DiffSimViz\backup\diffsimviz_debug.ipynb Cell 7 line <cell line: 11>()
#      <a href='vscode-notebook-cell:/c%3A/Users/evanc/OneDrive%20-%20University%20of%20Waterloo/DiffSimViz/backup/diffsimviz_debug.ipynb#X20sZmlsZQ%3D%3D?line=27'>28</a>     plt.xlim((-1.5, 1.5))   # set the xlim to left, right
#      <a href='vscode-notebook-cell:/c%3A/Users/evanc/OneDrive%20-%20University%20of%20Waterloo/DiffSimViz/backup/diffsimviz_debug.ipynb#X20sZmlsZQ%3D%3D?line=28'>29</a>     plt.ylim((-1.5, 1.5))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/evanc/OneDrive%20-%20University%20of%20Waterloo/DiffSimViz/backup/diffsimviz_debug.ipynb#X20sZmlsZQ%3D%3D?line=31'>32</a> plt.savefig(f'{outputdirectory}/test_{i}.png')
#      <a href='vscode-notebook-cell:/c%3A/Users/evanc/OneDrive%20-%20University%20of%20Waterloo/DiffSimViz/backup/diffsimviz_debug.ipynb#X20sZmlsZQ%3D%3D?line=32'>33</a> filenames.append(f'test_{i}.png')
#      <a href='vscode-notebook-cell:/c%3A/Users/evanc/OneDrive%20-%20University%20of%20Waterloo/DiffSimViz/backup/diffsimviz_debug.ipynb#X20sZmlsZQ%3D%3D?line=33'>34</a> #ax.clear()
#      <a href='vscode-notebook-cell:/c%3A/Users/evanc/OneDrive%20-%20University%20of%20Waterloo/DiffSimViz/backup/diffsimviz_debug.ipynb#X20sZmlsZQ%3D%3D?line=34'>35</a> #display(fig)
#
# NameError: name 'outputdirectory' is not defined

# %% [markdown]
# # Stick Cross

# %%
# Create brownian singlestep function for cross, where there are two pair of walls aka sticks.
from math import sqrt
from scipy.stats import norm
import numpy as np

def brownian_singlestep_cross(x0, n, dt, delta, radius, vradius, theta, out=None):
    x0 = np.asarray(x0)
    # For each element of x0, generate a sample of n numbers from a
    # normal distribution.
    coordhold = np.copy(x0)
    coordfinal = np.zeros((2,n))
    #coordfinal = []

    c, s = np.cos(theta), np.sin(theta)
    rot = np.array(((c, -s), (s, c)))
    # Quadrant 1 check
    if x0[0] >  radius and x0[1] > vradius: 
        where=0
        for i in range(n):
            print(i)
            print("Q1 For Loop")
            if i == 0:
                coordfinal[:,0] = x0
                print("Q1 If Statement")
            else:
                print("Q1 Else Statement")
                r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                if (r[0] + coordhold[0]) > radius and (r[1] + coordhold[1]) > vradius:
                    print("Q1 Else If Statement")
                    coordhold += r
                    coordfinal[:,i] = coordhold
                else:
                    print("Q1 Else Else Statement")
                    while (r[0] + coordhold[0]) < radius or (r[1] + coordhold[1]) < vradius:
                        print("Q1 Else Else While Statement")
                        r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                    coordhold += r
                    coordfinal[:,i] = coordhold
                    print("Q1 Else Else Post-While Statement")
    # Quadrant 2 check
    elif x0[0] < -radius and x0[1] > vradius:
        where = 0
        for i in range(n):
            print(i)
            print("Quadrant 2, Iteration:", i)
            if i == 0:
                coordfinal[:,0] = x0
            else:
                r = norm.rvs(size=(2,), scale=delta*sqrt(dt))
                if (r[0] + coordhold[0]) < -radius and (r[1] + coordhold[1]) > vradius:
                    coordhold += r
                    coordfinal[:,i] = coordhold
                else:
                    print("Entering Quadrant 2 While Loop")
                    while (r[0] + coordhold[0]) > -radius or (r[1] + coordhold[1]) < vradius:
                        r = norm.rvs(size=(2,), scale=delta*sqrt(dt))
                        print("Inside Quadrant 2 While Loop")
                    coordhold += r
                    coordfinal[:,i] = coordhold
    # Quadrant 3 check
    elif x0[0] < -radius and x0[1] < -vradius:
        where=0
        for i in range(n):
            print(i)
            print("Q3 For Loop")
            if i == 0:
                coordfinal[:,0] = x0
                print("Q3 If Statement")
            else:
                print("Q3 Else Statement")
                r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                if (r[0] + coordhold[0]) < -radius and (r[1] + coordhold[1]) < -vradius:
                    print("Q3 Else If Statement")
                    coordhold += r
                    coordfinal[:,i] = coordhold
                else:
                    print("Q3 Else Else Statement")
                    while (r[0] + coordhold[0]) > -radius or (r[1] + coordhold[1]) > -vradius:
                        print("Q3 Else Else While Statement")
                        r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                    coordhold += r
                    coordfinal[:,i] = coordhold
                    print("Q3 Else Else Post-While Statement")
    # Quadrant 4 check
    elif x0[0] > radius and x0[1] < -vradius:
        where=0
        for i in range(n):
            print("Q4 For Loop")
            print(i)
            if i == 0:
                coordfinal[:,0] = x0
                print("Q4 If Statement")
            else:
                print("Q4 Else Statement")
                r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                if (r[0] + coordhold[0]) > radius and (r[1] + coordhold[1]) < -vradius:
                    print("Q4 Else If Statement")
                    coordhold += r
                    coordfinal[:,i] = coordhold
                else:
                    print("Q4 Else Else Statement")
                    while (r[0] + coordhold[0]) < radius or (r[1] + coordhold[1]) > -vradius:
                        print("Q4 Else Else While Statement")
                        r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                    coordhold += r
                    coordfinal[:,i] = coordhold
                    print("Q4 Else Else Post-While Statement")

    # horizontal stick check
    # Does not need to check is x0 is above or below the stick as it is already checked in the quadrant checks
    elif x0[1] < vradius and x0[1] > -vradius: 
        where=1
        for i in range(n):
            print(i)
            print("Horizontal Stick For Loop")
            if i == 0:
                coordfinal[:,0] = x0
            else:
                r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                if (r[1] + coordhold[1]) < vradius and (r[1] + coordhold[1]) > -vradius:
                    coordhold += r
                    coordfinal[:,i] = coordhold
                else:
                    while (r[1] + coordhold[1]) > vradius or (r[1] + coordhold[1]) < -vradius:
                        r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                    coordhold += r
                    coordfinal[:,i] = coordhold
    # else case should be the vertical stick check
    elif x0[0] > -radius and x0[0] < radius:
        where=0
        where = 1
        for i in range(n):
            print(i)
            print("vertical stick case")
            if i == 0:
                print("vstick if")
                coordfinal[:,0] = x0
            else:
                r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                print("vstick else")
                if (r[0] + coordhold[0]) > -radius and (r[0] + coordhold[0]) < radius:
                    print("vstick else > if")
                    coordhold += r
                    coordfinal[:,i] = coordhold
                else:
                    print("vstick else > else")
                    while (r[0] + coordhold[0]) < -radius or (r[0] + coordhold[0]) > radius:
                        print("vstick else > else > while")
                        r = norm.rvs(size=(2,),scale=delta*sqrt(dt))
                    coordhold += r
                    coordfinal[:,i] = coordhold
    else:
        print("conditionals failed")
        print(x0)

    coordfinal = np.squeeze(np.array(coordfinal)) 
    # Add the initial condition.
    #coordfinal += np.expand_dims(x0, axis=-1)
    coordfinal = np.transpose(rot) @ coordfinal
    initialrot = np.transpose(rot) @ x0
    
    return coordfinal,where,initialrot

# %%
# What's probably more efficient is to have a counter of how many particles need to be in each area, and then reduce a counter as particles are placed in each area.
# Then, if the counter is 0, then the particles can't be placed in that area.
# Two Pairs (CROSS)
# In vertical stick, generate initial position/coordinate in top area only.
initialinx = numpy.random.uniform(low=-radius, high=radius, size=(round(numofmol*ratiointra*0.25)*2,1))
initialiny = numpy.random.uniform(low=vradius, high=1.5, size=(round(numofmol*ratiointra*0.25),1))
initialiny2= numpy.random.uniform(low=-1.5, high=-vradius, size=(round(numofmol*ratiointra*0.25),1))
initialiny = np.concatenate((initialiny,initialiny2),axis=1).T
initialinVStick = np.concatenate((initialinx,initialiny),axis=1)

initialinx = numpy.random.uniform(low=-1.5,high=-radius,size=(round(numofmol*ratiointra*0.25),1))
initialinx2= numpy.random.uniform(low=radius,high=1.5,size=(round(numofmol*ratiointra*0.25),1))
initialinx = np.concatenate((initialinx,initialinx2),axis=1).T
initialiny = numpy.random.uniform(low=-vradius,high=vradius,size=(round(numofmol*ratiointra*0.25)*2,1))
initialinHStick = np.concatenate((initialinx,initialiny),axis=1)

initialQ1x = numpy.random.uniform(low=radius,high=1.5,size=(round(numofmol*(1-ratiointra)*0.25),1))
initialQ1y = numpy.random.uniform(low=vradius,high=1.5,size=(round(numofmol*(1-ratiointra)*0.25),1))
initialQ1 = np.concatenate((initialQ1x,initialQ1y),axis=1)

initialQ2x = numpy.random.uniform(low=-1.5,high=-radius,size=(round(numofmol*(1-ratiointra)*0.25),1))
initialQ2y = numpy.random.uniform(low=vradius,high=1.5,size=(round(numofmol*(1-ratiointra)*0.25),1))
initialQ2 = np.concatenate((initialQ2x,initialQ2y),axis=1)

initialQ3x = numpy.random.uniform(low=-1.5,high=-radius,size=(round(numofmol*(1-ratiointra)*0.25),1))
initialQ3y = numpy.random.uniform(low=-1.5,high=-vradius,size=(round(numofmol*(1-ratiointra)*0.25),1))
initialQ3 = np.concatenate((initialQ3x,initialQ3y),axis=1)

initialQ4x = numpy.random.uniform(low=radius,high=1.5,size=(round(numofmol*(1-ratiointra)*0.25),1))
initialQ4y = numpy.random.uniform(low=-1.5,high=-vradius,size=(round(numofmol*(1-ratiointra)*0.25),1))
initialQ4 = np.concatenate((initialQ4x,initialQ4y),axis=1)

initialQcomb = np.concatenate((initialQ1,initialQ2,initialQ3,initialQ4),axis=0)

initial = np.concatenate((initialinVStick,initialinHStick,initialQcomb),axis=0)
print("finished generating")
# There appear to be no issues with the initial positions.
# Out:
# finished generating

# %%
where = np.zeros(numofmol) # initialize where to a default value
for i in range(numofmol):
    print("mol #",i)
    print(initial[i,:])
    [traj[:,:,i],where[i],initialrot[i,:]] = brownian_singlestep_cross(initial[i,:], N, dt, delta,radius,vradius,theta)
# Out:
# mol # 0
# [-0.07024912  0.88220138]
# 0
# vertical stick case
# vstick if
# 1
# vertical stick case
# vstick else
# vstick else > if
# 2
# vertical stick case
# vstick else
# vstick else > if
# 3
# vertical stick case
# vstick else
# vstick else > if
# 4
# vertical stick case
# vstick else
# vstick else > if
# 5
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 6
# vertical stick case
# vstick else
# vstick else > if
# 7
# vertical stick case
# vstick else
# vstick else > if
# 8
# vertical stick case
# vstick else
# vstick else > if
# 9
# vertical stick case
# vstick else
# vstick else > if
# 10
# vertical stick case
# vstick else
# vstick else > if
# 11
# vertical stick case
# vstick else
# vstick else > if
# 12
# vertical stick case
# vstick else
# vstick else > if
# 13
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# vstick else > else > while
# 14
# vertical stick case
# vstick else
# vstick else > if
# 15
# vertical stick case
# vstick else
# vstick else > if
# 16
# vertical stick case
# vstick else
# vstick else > if
# 17
# vertical stick case
# vstick else
# vstick else > if
# 18
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 19
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 20
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 21
# vertical stick case
# vstick else
# vstick else > if
# 22
# vertical stick case
# vstick else
# vstick else > if
# 23
# vertical stick case
# vstick else
# vstick else > if
# 24
# vertical stick case
# vstick else
# vstick else > if
# 25
# vertical stick case
# vstick else
# vstick else > if
# 26
# vertical stick case
# vstick else
# vstick else > if
# 27
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# vstick else > else > while
# vstick else > else > while
# 28
# vertical stick case
# vstick else
# vstick else > if
# 29
# vertical stick case
# vstick else
# vstick else > if
# 30
# vertical stick case
# vstick else
# vstick else > if
# 31
# vertical stick case
# vstick else
# vstick else > if
# 32
# vertical stick case
# vstick else
# vstick else > if
# 33
# vertical stick case
# vstick else
# vstick else > if
# 34
# vertical stick case
# vstick else
# vstick else > if
# 35
# vertical stick case
# vstick else
# vstick else > if
# 36
# vertical stick case
# vstick else
# vstick else > if
# 37
# vertical stick case
# vstick else
# vstick else > if
# 38
# vertical stick case
# vstick else
# vstick else > if
# 39
# vertical stick case
# vstick else
# vstick else > if
# 40
# vertical stick case
# vstick else
# vstick else > if
# 41
# vertical stick case
# vstick else
# vstick else > if
# 42
# vertical stick case
# vstick else
# vstick else > if
# 43
# vertical stick case
# vstick else
# vstick else > if
# 44
# vertical stick case
# vstick else
# vstick else > if
# 45
# vertical stick case
# vstick else
# vstick else > if
# 46
# vertical stick case
# vstick else
# vstick else > if
# 47
# vertical stick case
# vstick else
# vstick else > if
# 48
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 49
# vertical stick case
# vstick else
# vstick else > if
# 50
# vertical stick case
# vstick else
# vstick else > if
# 51
# vertical stick case
# vstick else
# vstick else > if
# 52
# vertical stick case
# vstick else
# vstick else > if
# 53
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# vstick else > else > while
# 54
# vertical stick case
# vstick else
# vstick else > if
# 55
# vertical stick case
# vstick else
# vstick else > if
# 56
# vertical stick case
# vstick else
# vstick else > if
# 57
# vertical stick case
# vstick else
# vstick else > if
# 58
# vertical stick case
# vstick else
# vstick else > if
# 59
# vertical stick case
# vstick else
# vstick else > if
# 60
# vertical stick case
# vstick else
# vstick else > if
# 61
# vertical stick case
# vstick else
# vstick else > if
# 62
# vertical stick case
# vstick else
# vstick else > if
# 63
# vertical stick case
# vstick else
# vstick else > if
# 64
# vertical stick case
# vstick else
# vstick else > if
# 65
# vertical stick case
# vstick else
# vstick else > if
# 66
# vertical stick case
# vstick else
# vstick else > if
# 67
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 68
# vertical stick case
# vstick else
# vstick else > if
# 69
# vertical stick case
# vstick else
# vstick else > if
# 70
# vertical stick case
# vstick else
# vstick else > if
# 71
# vertical stick case
# vstick else
# vstick else > if
# 72
# vertical stick case
# vstick else
# vstick else > if
# 73
# vertical stick case
# vstick else
# vstick else > if
# 74
# vertical stick case
# vstick else
# vstick else > if
# 75
# vertical stick case
# vstick else
# vstick else > if
# 76
# vertical stick case
# vstick else
# vstick else > if
# 77
# vertical stick case
# vstick else
# vstick else > if
# 78
# vertical stick case
# vstick else
# vstick else > if
# 79
# vertical stick case
# vstick else
# vstick else > if
# 80
# vertical stick case
# vstick else
# vstick else > if
# 81
# vertical stick case
# vstick else
# vstick else > if
# 82
# vertical stick case
# vstick else
# vstick else > if
# 83
# vertical stick case
# vstick else
# vstick else > if
# 84
# vertical stick case
# vstick else
# vstick else > if
# 85
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# vstick else > else > while
# vstick else > else > while
# 86
# vertical stick case
# vstick else
# vstick else > if
# 87
# vertical stick case
# vstick else
# vstick else > if
# 88
# vertical stick case
# vstick else
# vstick else > if
# 89
# vertical stick case
# vstick else
# vstick else > if
# 90
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# vstick else > else > while
# vstick else > else > while
# 91
# vertical stick case
# vstick else
# vstick else > if
# 92
# vertical stick case
# vstick else
# vstick else > if
# 93
# vertical stick case
# vstick else
# vstick else > if
# 94
# vertical stick case
# vstick else
# vstick else > if
# 95
# vertical stick case
# vstick else
# vstick else > if
# 96
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 97
# vertical stick case
# vstick else
# vstick else > if
# 98
# vertical stick case
# vstick else
# vstick else > if
# 99
# vertical stick case
# vstick else
# vstick else > if
# mol # 1
# [ 0.11842138 -1.00897707]
# 0
# vertical stick case
# vstick if
# 1
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 2
# vertical stick case
# vstick else
# vstick else > if
# 3
# vertical stick case
# vstick else
# vstick else > if
# 4
# vertical stick case
# vstick else
# vstick else > if
# 5
# vertical stick case
# vstick else
# vstick else > if
# 6
# vertical stick case
# vstick else
# vstick else > if
# 7
# vertical stick case
# vstick else
# vstick else > if
# 8
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 9
# vertical stick case
# vstick else
# vstick else > if
# 10
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 11
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 12
# vertical stick case
# vstick else
# vstick else > if
# 13
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 14
# vertical stick case
# vstick else
# vstick else > if
# 15
# vertical stick case
# vstick else
# vstick else > if
# 16
# vertical stick case
# vstick else
# vstick else > if
# 17
# vertical stick case
# vstick else
# vstick else > if
# 18
# vertical stick case
# vstick else
# vstick else > if
# 19
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 20
# vertical stick case
# vstick else
# vstick else > if
# 21
# vertical stick case
# vstick else
# vstick else > if
# 22
# vertical stick case
# vstick else
# vstick else > if
# 23
# vertical stick case
# vstick else
# vstick else > if
# 24
# vertical stick case
# vstick else
# vstick else > if
# 25
# vertical stick case
# vstick else
# vstick else > if
# 26
# vertical stick case
# vstick else
# vstick else > if
# 27
# vertical stick case
# vstick else
# vstick else > if
# 28
# vertical stick case
# vstick else
# vstick else > if
# 29
# vertical stick case
# vstick else
# vstick else > if
# 30
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 31
# vertical stick case
# vstick else
# vstick else > if
# 32
# vertical stick case
# vstick else
# vstick else > if
# 33
# vertical stick case
# vstick else
# vstick else > if
# 34
# vertical stick case
# vstick else
# vstick else > if
# 35
# vertical stick case
# vstick else
# vstick else > if
# 36
# vertical stick case
# vstick else
# vstick else > if
# 37
# vertical stick case
# vstick else
# vstick else > if
# 38
# vertical stick case
# vstick else
# vstick else > if
# 39
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 40
# vertical stick case
# vstick else
# vstick else > if
# 41
# vertical stick case
# vstick else
# vstick else > if
# 42
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# vstick else > else > while
# 43
# vertical stick case
# vstick else
# vstick else > if
# 44
# vertical stick case
# vstick else
# vstick else > if
# 45
# vertical stick case
# vstick else
# vstick else > if
# 46
# vertical stick case
# vstick else
# vstick else > if
# 47
# vertical stick case
# vstick else
# vstick else > if
# 48
# vertical stick case
# vstick else
# vstick else > if
# 49
# vertical stick case
# vstick else
# vstick else > if
# 50
# vertical stick case
# vstick else
# vstick else > if
# 51
# vertical stick case
# vstick else
# vstick else > if
# 52
# vertical stick case
# vstick else
# vstick else > if
# 53
# vertical stick case
# vstick else
# vstick else > if
# 54
# vertical stick case
# vstick else
# vstick else > if
# 55
# vertical stick case
# vstick else
# vstick else > if
# 56
# vertical stick case
# vstick else
# vstick else > if
# 57
# vertical stick case
# vstick else
# vstick else > if
# 58
# vertical stick case
# vstick else
# vstick else > if
# 59
# vertical stick case
# vstick else
# vstick else > if
# 60
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# vstick else > else > while
# vstick else > else > while
# vstick else > else > while
# 61
# vertical stick case
# vstick else
# vstick else > if
# 62
# vertical stick case
# vstick else
# vstick else > if
# 63
# vertical stick case
# vstick else
# vstick else > if
# 64
# vertical stick case
# vstick else
# vstick else > if
# 65
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# vstick else > else > while
# vstick else > else > while
# 66
# vertical stick case
# vstick else
# vstick else > if
# 67
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 68
# vertical stick case
# vstick else
# vstick else > if
# 69
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 70
# vertical stick case
# vstick else
# vstick else > if
# 71
# vertical stick case
# vstick else
# vstick else > if
# 72
# vertical stick case
# vstick else
# vstick else > if
# 73
# vertical stick case
# vstick else
# vstick else > if
# 74
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 75
# vertical stick case
# vstick else
# vstick else > if
# 76
# vertical stick case
# vstick else
# vstick else > if
# 77
# vertical stick case
# vstick else
# vstick else > if
# 78
# vertical stick case
# vstick else
# vstick else > if
# 79
# vertical stick case
# vstick else
# vstick else > if
# 80
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 81
# vertical stick case
# vstick else
# vstick else > if
# 82
# vertical stick case
# vstick else
# vstick else > if
# 83
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 84
# vertical stick case
# vstick else
# vstick else > if
# 85
# vertical stick case
# vstick else
# vstick else > if
# 86
# vertical stick case
# vstick else
# vstick else > if
# 87
# vertical stick case
# vstick else
# vstick else > if
# 88
# vertical stick case
# vstick else
# vstick else > if
# 89
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 90
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 91
# vertical stick case
# vstick else
# vstick else > if
# 92
# vertical stick case
# vstick else
# vstick else > if
# 93
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 94
# vertical stick case
# vstick else
# vstick else > if
# 95
# vertical stick case
# vstick else
# vstick else > if
# 96
# vertical stick case
# vstick else
# vstick else > if
# 97
# vertical stick case
# vstick else
# vstick else > if
# 98
# vertical stick case
# vstick else
# vstick else > else
# vstick else > else > while
# 99
# vertical stick case
# vstick else
# vstick else > if
# mol # 2
# [-1.16443063  0.14219424]
# 0
# Horizontal Stick For Loop
# 1
# Horizontal Stick For Loop
# 2
# Horizontal Stick For Loop
# 3
# Horizontal Stick For Loop
# 4
# Horizontal Stick For Loop
# 5
# Horizontal Stick For Loop
# 6
# Horizontal Stick For Loop
# 7
# Horizontal Stick For Loop
# 8
# Horizontal Stick For Loop
# 9
# Horizontal Stick For Loop
# 10
# Horizontal Stick For Loop
# 11
# Horizontal Stick For Loop
# 12
# Horizontal Stick For Loop
# 13
# Horizontal Stick For Loop
# 14
# Horizontal Stick For Loop
# 15
# Horizontal Stick For Loop
# 16
# Horizontal Stick For Loop
# 17
# Horizontal Stick For Loop
# 18
# Horizontal Stick For Loop
# 19
# Horizontal Stick For Loop
# 20
# Horizontal Stick For Loop
# 21
# Horizontal Stick For Loop
# 22
# Horizontal Stick For Loop
# 23
# Horizontal Stick For Loop
# 24
# Horizontal Stick For Loop
# 25
# Horizontal Stick For Loop
# 26
# Horizontal Stick For Loop
# 27
# Horizontal Stick For Loop
# 28
# Horizontal Stick For Loop
# 29
# Horizontal Stick For Loop
# 30
# Horizontal Stick For Loop
# 31
# Horizontal Stick For Loop
# 32
# Horizontal Stick For Loop
# 33
# Horizontal Stick For Loop
# 34
# Horizontal Stick For Loop
# 35
# Horizontal Stick For Loop
# 36
# Horizontal Stick For Loop
# 37
# Horizontal Stick For Loop
# 38
# Horizontal Stick For Loop
# 39
# Horizontal Stick For Loop
# 40
# Horizontal Stick For Loop
# 41
# Horizontal Stick For Loop
# 42
# Horizontal Stick For Loop
# 43
# Horizontal Stick For Loop
# 44
# Horizontal Stick For Loop
# 45
# Horizontal Stick For Loop
# 46
# Horizontal Stick For Loop
# 47
# Horizontal Stick For Loop
# 48
# Horizontal Stick For Loop
# 49
# Horizontal Stick For Loop
# 50
# Horizontal Stick For Loop
# 51
# Horizontal Stick For Loop
# 52
# Horizontal Stick For Loop
# 53
# Horizontal Stick For Loop
# 54
# Horizontal Stick For Loop
# 55
# Horizontal Stick For Loop
# 56
# Horizontal Stick For Loop
# 57
# Horizontal Stick For Loop
# 58
# Horizontal Stick For Loop
# 59
# Horizontal Stick For Loop
# 60
# Horizontal Stick For Loop
# 61
# Horizontal Stick For Loop
# 62
# Horizontal Stick For Loop
# 63
# Horizontal Stick For Loop
# 64
# Horizontal Stick For Loop
# 65
# Horizontal Stick For Loop
# 66
# Horizontal Stick For Loop
# 67
# Horizontal Stick For Loop
# 68
# Horizontal Stick For Loop
# 69
# Horizontal Stick For Loop
# 70
# Horizontal Stick For Loop
# 71
# Horizontal Stick For Loop
# 72
# Horizontal Stick For Loop
# 73
# Horizontal Stick For Loop
# 74
# Horizontal Stick For Loop
# 75
# Horizontal Stick For Loop
# 76
# Horizontal Stick For Loop
# 77
# Horizontal Stick For Loop
# 78
# Horizontal Stick For Loop
# 79
# Horizontal Stick For Loop
# 80
# Horizontal Stick For Loop
# 81
# Horizontal Stick For Loop
# 82
# Horizontal Stick For Loop
# 83
# Horizontal Stick For Loop
# 84
# Horizontal Stick For Loop
# 85
# Horizontal Stick For Loop
# 86
# Horizontal Stick For Loop
# 87
# Horizontal Stick For Loop
# 88
# Horizontal Stick For Loop
# 89
# Horizontal Stick For Loop
# 90
# Horizontal Stick For Loop
# 91
# Horizontal Stick For Loop
# 92
# Horizontal Stick For Loop
# 93
# Horizontal Stick For Loop
# 94
# Horizontal Stick For Loop
# 95
# Horizontal Stick For Loop
# 96
# Horizontal Stick For Loop
# 97
# Horizontal Stick For Loop
# 98
# Horizontal Stick For Loop
# 99
# Horizontal Stick For Loop
# mol # 3
# [ 0.36588107 -0.07893798]
# 0
# Horizontal Stick For Loop
# 1
# Horizontal Stick For Loop
# 2
# Horizontal Stick For Loop
# 3
# Horizontal Stick For Loop
# 4
# Horizontal Stick For Loop
# 5
# Horizontal Stick For Loop
# 6
# Horizontal Stick For Loop
# 7
# Horizontal Stick For Loop
# 8
# Horizontal Stick For Loop
# 9
# Horizontal Stick For Loop
# 10
# Horizontal Stick For Loop
# 11
# Horizontal Stick For Loop
# 12
# Horizontal Stick For Loop
# 13
# Horizontal Stick For Loop
# 14
# Horizontal Stick For Loop
# 15
# Horizontal Stick For Loop
# 16
# Horizontal Stick For Loop
# 17
# Horizontal Stick For Loop
# 18
# Horizontal Stick For Loop
# 19
# Horizontal Stick For Loop
# 20
# Horizontal Stick For Loop
# 21
# Horizontal Stick For Loop
# 22
# Horizontal Stick For Loop
# 23
# Horizontal Stick For Loop
# 24
# Horizontal Stick For Loop
# 25
# Horizontal Stick For Loop
# 26
# Horizontal Stick For Loop
# 27
# Horizontal Stick For Loop
# 28
# Horizontal Stick For Loop
# 29
# Horizontal Stick For Loop
# 30
# Horizontal Stick For Loop
# 31
# Horizontal Stick For Loop
# 32
# Horizontal Stick For Loop
# 33
# Horizontal Stick For Loop
# 34
# Horizontal Stick For Loop
# 35
# Horizontal Stick For Loop
# 36
# Horizontal Stick For Loop
# 37
# Horizontal Stick For Loop
# 38
# Horizontal Stick For Loop
# 39
# Horizontal Stick For Loop
# 40
# Horizontal Stick For Loop
# 41
# Horizontal Stick For Loop
# 42
# Horizontal Stick For Loop
# 43
# Horizontal Stick For Loop
# 44
# Horizontal Stick For Loop
# 45
# Horizontal Stick For Loop
# 46
# Horizontal Stick For Loop
# 47
# Horizontal Stick For Loop
# 48
# Horizontal Stick For Loop
# 49
# Horizontal Stick For Loop
# 50
# Horizontal Stick For Loop
# 51
# Horizontal Stick For Loop
# 52
# Horizontal Stick For Loop
# 53
# Horizontal Stick For Loop
# 54
# Horizontal Stick For Loop
# 55
# Horizontal Stick For Loop
# 56
# Horizontal Stick For Loop
# 57
# Horizontal Stick For Loop
# 58
# Horizontal Stick For Loop
# 59
# Horizontal Stick For Loop
# 60
# Horizontal Stick For Loop
# 61
# Horizontal Stick For Loop
# 62
# Horizontal Stick For Loop
# 63
# Horizontal Stick For Loop
# 64
# Horizontal Stick For Loop
# 65
# Horizontal Stick For Loop
# 66
# Horizontal Stick For Loop
# 67
# Horizontal Stick For Loop
# 68
# Horizontal Stick For Loop
# 69
# Horizontal Stick For Loop
# 70
# Horizontal Stick For Loop
# 71
# Horizontal Stick For Loop
# 72
# Horizontal Stick For Loop
# 73
# Horizontal Stick For Loop
# 74
# Horizontal Stick For Loop
# 75
# Horizontal Stick For Loop
# 76
# Horizontal Stick For Loop
# 77
# Horizontal Stick For Loop
# 78
# Horizontal Stick For Loop
# 79
# Horizontal Stick For Loop
# 80
# Horizontal Stick For Loop
# 81
# Horizontal Stick For Loop
# 82
# Horizontal Stick For Loop
# 83
# Horizontal Stick For Loop
# 84
# Horizontal Stick For Loop
# 85
# Horizontal Stick For Loop
# 86
# Horizontal Stick For Loop
# 87
# Horizontal Stick For Loop
# 88
# Horizontal Stick For Loop
# 89
# Horizontal Stick For Loop
# 90
# Horizontal Stick For Loop
# 91
# Horizontal Stick For Loop
# 92
# Horizontal Stick For Loop
# 93
# Horizontal Stick For Loop
# 94
# Horizontal Stick For Loop
# 95
# Horizontal Stick For Loop
# 96
# Horizontal Stick For Loop
# 97
# Horizontal Stick For Loop
# 98
# Horizontal Stick For Loop
# 99
# Horizontal Stick For Loop
# mol # 4
# [1.37531066 1.25611887]
# 0
# Q1 For Loop
# Q1 If Statement
# 1
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 2
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 3
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 4
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 5
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 6
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 7
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 8
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 9
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 10
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 11
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 12
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 13
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 14
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 15
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 16
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 17
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 18
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 19
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 20
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 21
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 22
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 23
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 24
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 25
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 26
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 27
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 28
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 29
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 30
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 31
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 32
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 33
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 34
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 35
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 36
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 37
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 38
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 39
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 40
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 41
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 42
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 43
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 44
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 45
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 46
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 47
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 48
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 49
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 50
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 51
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 52
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 53
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 54
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 55
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 56
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 57
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 58
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 59
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 60
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 61
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 62
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 63
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 64
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 65
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 66
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 67
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 68
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 69
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 70
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 71
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 72
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 73
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 74
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 75
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 76
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 77
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 78
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 79
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 80
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 81
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 82
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 83
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 84
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 85
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 86
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 87
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 88
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 89
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 90
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 91
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 92
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 93
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 94
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 95
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 96
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 97
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 98
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# 99
# Q1 For Loop
# Q1 Else Statement
# Q1 Else If Statement
# mol # 5
# [-1.43064095  1.15631359]
# 0
# Quadrant 2, Iteration: 0
# 1
# Quadrant 2, Iteration: 1
# 2
# Quadrant 2, Iteration: 2
# 3
# Quadrant 2, Iteration: 3
# 4
# Quadrant 2, Iteration: 4
# 5
# Quadrant 2, Iteration: 5
# 6
# Quadrant 2, Iteration: 6
# 7
# Quadrant 2, Iteration: 7
# 8
# Quadrant 2, Iteration: 8
# 9
# Quadrant 2, Iteration: 9
# 10
# Quadrant 2, Iteration: 10
# 11
# Quadrant 2, Iteration: 11
# 12
# Quadrant 2, Iteration: 12
# 13
# Quadrant 2, Iteration: 13
# 14
# Quadrant 2, Iteration: 14
# 15
# Quadrant 2, Iteration: 15
# 16
# Quadrant 2, Iteration: 16
# 17
# Quadrant 2, Iteration: 17
# 18
# Quadrant 2, Iteration: 18
# 19
# Quadrant 2, Iteration: 19
# 20
# Quadrant 2, Iteration: 20
# 21
# Quadrant 2, Iteration: 21
# 22
# Quadrant 2, Iteration: 22
# 23
# Quadrant 2, Iteration: 23
# 24
# Quadrant 2, Iteration: 24
# 25
# Quadrant 2, Iteration: 25
# 26
# Quadrant 2, Iteration: 26
# 27
# Quadrant 2, Iteration: 27
# 28
# Quadrant 2, Iteration: 28
# 29
# Quadrant 2, Iteration: 29
# 30
# Quadrant 2, Iteration: 30
# 31
# Quadrant 2, Iteration: 31
# 32
# Quadrant 2, Iteration: 32
# 33
# Quadrant 2, Iteration: 33
# 34
# Quadrant 2, Iteration: 34
# 35
# Quadrant 2, Iteration: 35
# 36
# Quadrant 2, Iteration: 36
# 37
# Quadrant 2, Iteration: 37
# 38
# Quadrant 2, Iteration: 38
# 39
# Quadrant 2, Iteration: 39
# 40
# Quadrant 2, Iteration: 40
# 41
# Quadrant 2, Iteration: 41
# 42
# Quadrant 2, Iteration: 42
# 43
# Quadrant 2, Iteration: 43
# 44
# Quadrant 2, Iteration: 44
# 45
# Quadrant 2, Iteration: 45
# 46
# Quadrant 2, Iteration: 46
# 47
# Quadrant 2, Iteration: 47
# 48
# Quadrant 2, Iteration: 48
# 49
# Quadrant 2, Iteration: 49
# 50
# Quadrant 2, Iteration: 50
# Entering Quadrant 2 While Loop
# Inside Quadrant 2 While Loop
# Inside Quadrant 2 While Loop
# 51
# Quadrant 2, Iteration: 51
# Entering Quadrant 2 While Loop
# Inside Quadrant 2 While Loop
# 52
# Quadrant 2, Iteration: 52
# 53
# Quadrant 2, Iteration: 53
# Entering Quadrant 2 While Loop
# Inside Quadrant 2 While Loop
# 54
# Quadrant 2, Iteration: 54
# 55
# Quadrant 2, Iteration: 55
# 56
# Quadrant 2, Iteration: 56
# 57
# Quadrant 2, Iteration: 57
# Entering Quadrant 2 While Loop
# Inside Quadrant 2 While Loop
# 58
# Quadrant 2, Iteration: 58
# 59
# Quadrant 2, Iteration: 59
# 60
# Quadrant 2, Iteration: 60
# 61
# Quadrant 2, Iteration: 61
# 62
# Quadrant 2, Iteration: 62
# 63
# Quadrant 2, Iteration: 63
# 64
# Quadrant 2, Iteration: 64
# 65
# Quadrant 2, Iteration: 65
# 66
# Quadrant 2, Iteration: 66
# 67
# Quadrant 2, Iteration: 67
# 68
# Quadrant 2, Iteration: 68
# 69
# Quadrant 2, Iteration: 69
# 70
# Quadrant 2, Iteration: 70
# 71
# Quadrant 2, Iteration: 71
# 72
# Quadrant 2, Iteration: 72
# 73
# Quadrant 2, Iteration: 73
# 74
# Quadrant 2, Iteration: 74
# 75
# Quadrant 2, Iteration: 75
# 76
# Quadrant 2, Iteration: 76
# 77
# Quadrant 2, Iteration: 77
# 78
# Quadrant 2, Iteration: 78
# 79
# Quadrant 2, Iteration: 79
# 80
# Quadrant 2, Iteration: 80
# 81
# Quadrant 2, Iteration: 81
# 82
# Quadrant 2, Iteration: 82
# 83
# Quadrant 2, Iteration: 83
# 84
# Quadrant 2, Iteration: 84
# 85
# Quadrant 2, Iteration: 85
# 86
# Quadrant 2, Iteration: 86
# 87
# Quadrant 2, Iteration: 87
# 88
# Quadrant 2, Iteration: 88
# 89
# Quadrant 2, Iteration: 89
# 90
# Quadrant 2, Iteration: 90
# 91
# Quadrant 2, Iteration: 91
# 92
# Quadrant 2, Iteration: 92
# 93
# Quadrant 2, Iteration: 93
# 94
# Quadrant 2, Iteration: 94
# 95
# Quadrant 2, Iteration: 95
# 96
# Quadrant 2, Iteration: 96
# 97
# Quadrant 2, Iteration: 97
# 98
# Quadrant 2, Iteration: 98
# 99
# Quadrant 2, Iteration: 99
# mol # 6
# [-0.66357118 -1.4372894 ]
# 0
# Q3 For Loop
# Q3 If Statement
# 1
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 2
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 3
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 4
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 5
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 6
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 7
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 8
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 9
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 10
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 11
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 12
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 13
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 14
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 15
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 16
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 17
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 18
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 19
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 20
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 21
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 22
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 23
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 24
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 25
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 26
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 27
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 28
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 29
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 30
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 31
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 32
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 33
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 34
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 35
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 36
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 37
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 38
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 39
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 40
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 41
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 42
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 43
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 44
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 45
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 46
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 47
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 48
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 49
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 50
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 51
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 52
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 53
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 54
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 55
# Q3 For Loop
# Q3 Else Statement
# Q3 Else Else Statement
# Q3 Else Else While Statement
# Q3 Else Else While Statement
# Q3 Else Else While Statement
# Q3 Else Else Post-While Statement
# 56
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 57
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 58
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 59
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 60
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 61
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 62
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 63
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 64
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 65
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 66
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 67
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 68
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 69
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 70
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 71
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 72
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 73
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 74
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 75
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 76
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 77
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 78
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 79
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 80
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 81
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 82
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 83
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 84
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 85
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 86
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 87
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 88
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 89
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 90
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 91
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 92
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 93
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 94
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 95
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 96
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 97
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 98
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# 99
# Q3 For Loop
# Q3 Else Statement
# Q3 Else If Statement
# mol # 7
# [ 0.73500098 -0.47753848]
# Q4 For Loop
# 0
# Q4 If Statement
# Q4 For Loop
# 1
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 2
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 3
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 4
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 5
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 6
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 7
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 8
# Q4 Else Statement
# Q4 Else Else Statement
# Q4 Else Else While Statement
# Q4 Else Else Post-While Statement
# Q4 For Loop
# 9
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 10
# Q4 Else Statement
# Q4 Else Else Statement
# Q4 Else Else While Statement
# Q4 Else Else Post-While Statement
# Q4 For Loop
# 11
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 12
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 13
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 14
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 15
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 16
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 17
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 18
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 19
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 20
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 21
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 22
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 23
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 24
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 25
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 26
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 27
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 28
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 29
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 30
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 31
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 32
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 33
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 34
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 35
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 36
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 37
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 38
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 39
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 40
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 41
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 42
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 43
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 44
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 45
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 46
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 47
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 48
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 49
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 50
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 51
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 52
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 53
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 54
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 55
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 56
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 57
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 58
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 59
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 60
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 61
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 62
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 63
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 64
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 65
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 66
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 67
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 68
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 69
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 70
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 71
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 72
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 73
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 74
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 75
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 76
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 77
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 78
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 79
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 80
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 81
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 82
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 83
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 84
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 85
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 86
# Q4 Else Statement
# Q4 Else Else Statement
# Q4 Else Else While Statement
# Q4 Else Else Post-While Statement
# Q4 For Loop
# 87
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 88
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 89
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 90
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 91
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 92
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 93
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 94
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 95
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 96
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 97
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 98
# Q4 Else Statement
# Q4 Else If Statement
# Q4 For Loop
# 99
# Q4 Else Statement
# Q4 Else If Statement
# mol # 8
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\evanc\OneDrive - University of Waterloo\DiffSimViz\backup\diffsimviz_debug.ipynb Cell 11 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/evanc/OneDrive%20-%20University%20of%20Waterloo/DiffSimViz/backup/diffsimviz_debug.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> for i in range(numofmol):
#       <a href='vscode-notebook-cell:/c%3A/Users/evanc/OneDrive%20-%20University%20of%20Waterloo/DiffSimViz/backup/diffsimviz_debug.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     print("mol #",i)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/evanc/OneDrive%20-%20University%20of%20Waterloo/DiffSimViz/backup/diffsimviz_debug.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     print(initial[i,:])
#       <a href='vscode-notebook-cell:/c%3A/Users/evanc/OneDrive%20-%20University%20of%20Waterloo/DiffSimViz/backup/diffsimviz_debug.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     [traj[:,:,i],where[i],initialrot[i,:]] = brownian_singlestep_cross(initial[i,:], N, dt, delta,radius,vradius,theta)
#
# IndexError: index 8 is out of bounds for axis 0 with size 8

# %%
def make_horiz_line(theta,radius):
    
    x = np.linspace(-2,2,100)
    
    ylow = np.zeros((100,))
    yhigh = np.zeros((100,))
    ylow[:] = -vradius
    yhigh[:] = vradius
    
    line3=np.c_[x,ylow]
    line4=np.c_[x,yhigh]
    
    c, s = np.cos(theta), np.sin(theta)
    rot = np.array(((c, -s), (s, c)))
    
    line3rot = line3 @ rot
    line4rot = line4 @ rot
    
    return line3rot, line4rot
line3, line4 = make_horiz_line(theta,radius)

# %%
from IPython.display import display, clear_output
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111)
filenames = []

for i in range(N):
    print(i)
    for j in range(numofmol):

        new_y = traj[1,:i,j]
        new_x = traj[0,:i,j]

        if i == 0:
            ax.scatter(traj[0,0,j],traj[1,0,j],color='black')
        #elif i==N-1:
            #ax.scatter(traj[0,i,j],traj[1,i,j])
        if where[j] == 1:
            ax.plot(new_x,new_y,'deepskyblue')
        else:
            ax.plot(new_x,new_y,'lightskyblue')
        ax.plot(line1[:,0],line1[:,1],color='black')
        ax.plot(line2[:,0],line2[:,1],color='black')
        ax.plot(line3[:,0],line3[:,1],color='black')
        ax.plot(line4[:,0],line4[:,1],color='black')
        plt.xlim((-1.5, 1.5))   # set the xlim to left, right
        plt.ylim((-1.5, 1.5)) 


    plt.savefig(f'test_{i}.png')
    filenames.append(f'test_{i}.png')
    #ax.clear()
    #display(fig)
    clear_output(wait=True)

# %%
import imageio.v2 as imageio
with imageio.get_writer(f'{numofmol}mol_{theta}deg.gif', mode='I') as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)

# %% [markdown]
# # Now plot all points from the origin (universal)

# %%
origtraj = np.zeros((N,2,numofmol))

for i in range(numofmol):
    origtraj[:,0,i] = traj[0,:,i] - initialrot[i,0]
    origtraj[:,1,i] = traj[1,:,i] - initialrot[i,1]

# %%
from IPython.display import display, clear_output
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111)
filenames = []

for i in range(N):
    print(i)
    for j in range(numofmol):

        new_y = origtraj[:i,1,j]
        new_x = origtraj[:i,0,j]


        #ax.plot(new_x,new_y,'b')
        if where[j] == 1:
            ax.plot(new_x,new_y,'deepskyblue')
        else:
            ax.plot(new_x,new_y,'lightskyblue')


        plt.xlim((-1.5, 1.5))   # set the xlim to left, right
        plt.ylim((-1.5, 1.5)) 


    plt.savefig(f'test_{i}.png')
    filenames.append(f'test_{i}.png')
    #ax.clear()
    #display(fig)
    clear_output(wait=True)

# %%
import imageio.v2 as imageio
with imageio.get_writer(f'{numofmol}mol_{theta}degstick_origin.gif', mode='I') as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)

# %% [markdown]
# # Trying 3D

# %%
"""
brownian() implements one dimensional Brownian motion (i.e. the Wiener process).
"""

from math import sqrt
from scipy.stats import norm
import numpy as np


def brownian_singlestep(x0, n, dt, delta, radius, theta, out=None):
    """
    Generate an instance of Brownian motion (i.e. the Wiener process):

        X(t) = X(0) + N(0, delta**2 * t; 0, t)

    where N(a,b; t0, t1) is a normally distributed random variable with mean a and
    variance b.  The parameters t0 and t1 make explicit the statistical
    independence of N on different time intervals; that is, if [t0, t1) and
    [t2, t3) are disjoint intervals, then N(a, b; t0, t1) and N(a, b; t2, t3)
    are independent.
    
    Written as an iteration scheme,

        X(t + dt) = X(t) + N(0, delta**2 * dt; t, t+dt)


    If `x0` is an array (or array-like), each value in `x0` is treated as
    an initial condition, and the value returned is a numpy array with one
    more dimension than `x0`.

    Arguments
    ---------
    x0 : float or numpy array (or something that can be converted to a numpy array
         using numpy.asarray(x0)).
        The initial condition(s) (i.e. position(s)) of the Brownian motion.
    n : int
        The number of steps to take.
    dt : float
        The time step.
    delta : float
        delta determines the "speed" of the Brownian motion.  The random variable
        of the position at time t, X(t), has a normal distribution whose mean is
        the position at time t=0 and whose variance is delta**2*t.
    out : numpy array or None
        If `out` is not None, it specifies the array in which to put the
        result.  If `out` is None, a new numpy array is created and returned.

    Returns
    -------
    A numpy array of floats with shape `x0.shape + (n,)`.
    
    Note that the initial value `x0` is not included in the returned array.
    """

    x0 = np.asarray(x0)

    # For each element of x0, generate a sample of n numbers from a
    # normal distribution.
    coordhold = np.copy(x0)
    coordfinal = np.zeros((3,n))
    #coordfinal = []

    #c, s = np.cos(theta), np.sin(theta)
    #rot = np.array(((c, -s), (s, c)))


    if x0[0] < -radius:
        print('less than -')
        for i in range(n):
            #print(i)
            r = norm.rvs(size=(3,),scale=delta*sqrt(dt))
            if (r[0] + coordhold[0]) < -radius:
                coordhold += r
                coordfinal[:,i] = coordhold
            else:
                while (r[0] + coordhold[0]) > -radius:
                    r = norm.rvs(size=(3,),scale=delta*sqrt(dt))
                coordhold += r
                coordfinal[:,i] = coordhold
    elif x0[0] > radius:
        print('greater than +')
        for i in range(n):
            #print(i)
            r = norm.rvs(size=(3,),scale=delta*sqrt(dt))
            if (r[0] + coordhold[0]) > radius:
                coordhold += r
                coordfinal[:,i] = coordhold
            else:
                while (r[0] + coordhold[0]) < radius:
                    r = norm.rvs(size=(3,),scale=delta*sqrt(dt))
                coordhold += r
                coordfinal[:,i] = coordhold
    else:
        print('inside')
        for i in range(n):
            #print(i)
            r = norm.rvs(size=(3,),scale=delta*sqrt(dt))
            if (r[0] + coordhold[0]) > -radius and (r[0] + coordhold[0]) < radius and (r[1] + coordhold[1]) > -radius and (r[1] + coordhold[1]) < radius:
                coordhold += r
                coordfinal[:,i] = coordhold
            else:
                while (r[0] + coordhold[0]) < -radius or (r[0] + coordhold[0]) > radius:
                    r = norm.rvs(size=(3,),scale=delta*sqrt(dt))
                coordhold += r
                coordfinal[:,i] = coordhold

    coordfinal = np.squeeze(np.array(coordfinal))

    # Add the initial condition.
    #coordfinal += np.expand_dims(x0, axis=-1)

    #coordfinal = rot @ coordfinal

    return coordfinal
